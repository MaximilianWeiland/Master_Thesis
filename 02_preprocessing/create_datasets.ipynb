# %%
# load all libraries
import pandas as pd

# load the main dataset
parlspeech_df = pd.read_csv("../01_data/main_dataset/parlspeech_dataset.csv")

# load the BES datasets
bes_2015_df = pd.read_spss("../01_data/bes/2015/bes_2015.sav")
bes_2017_df = pd.read_spss("../01_data/bes/2017/bes_2017.sav")
bes_2019_df = pd.read_spss("../01_data/bes/2019/bes_2019.sav")

# %%
# set the election dates
election_dates = pd.to_datetime(["2010-05-06", "2015-05-07", "2017-06-08", "2019-12-12"])

# subset parlspeech df to research period
parlspeech_df["date"] = pd.to_datetime(parlspeech_df["date"])
research_period = parlspeech_df[parlspeech_df["date"] >= election_dates[0]]
