# %%
import numpy as np
import matplotlib.pyplot as plt
import json

from pathlib import Path
import sys
project_root = Path.cwd() / "../../"
sys.path.append(str(project_root))

from utils.visualizations import (
    within_metric_barplot, within_metric_dotplot,
    multi_within_metric_barplot, multi_within_metric_dotplot,
    across_metric_barplot, across_metric_dotplot,
    few_shot_dev, multi_few_shot_dev
)

# %% [markdown]
# # **Data Loading**

# %%
# import all json files
with open("cross_val_results/evaluation_metrics_bert_stance_sequence.json", "r") as f:
    bert_results = json.load(f)

with open("cross_val_results/evaluation_metrics_dictionary_stance.json", "r") as f:
    dictionary_results = json.load(f)

with open("cross_val_results/evaluation_metrics_bert_stance_nli.json", "r") as f:
    nli_results = json.load(f)

with open("cross_val_results/evaluation_metrics_gen_llm_stance.json", "r") as f:
    gpt_results = json.load(f)

# combine all models
all_results = {**bert_results, **dictionary_results, **nli_results, **gpt_results}

# reorder the dictionaries
bert_results = dict(
    (k, bert_results[k]) for k in [
        'microsoft/deberta-v3-base',
        'roberta-base',
        'bert-base-cased',
        'distilbert-base-cased'
    ]
)
gpt_results = dict(
    (k, gpt_results[k]) for k in [
        'gpt-5-nano',
        'gpt-4o-mini'
    ]
)

all_results = dict(
    (k, all_results[k]) for k in [
        'MoritzLaurer/deberta-v3-base-zeroshot-v2.0',
        'microsoft/deberta-v3-base',
        'roberta-base',
        'bert-base-cased',
        'distilbert-base-cased',
        'dictionary',
        'gpt-5-nano',
        'gpt-4o-mini'
    ]
)

# %%
gpt_results
# Out:
# {'gpt-5-nano': {'1_few_shot': {'negative': {'precision': {'mean': 0.4630651682059271,
#      'sd': 0.06078587920924033,
#      'lower': 0.4097839958762177,
#      'upper': 0.5163463405356364},
#     'recall': {'mean': 0.5913978494623655,
#      'sd': 0.10557365770867591,
#      'lower': 0.49885845835656706,
#      'upper': 0.683937240568164},
#     'f1': {'mean': 0.5182300397904924,
#      'sd': 0.07597054128824797,
#      'lower': 0.45163892430416547,
#      'upper': 0.5848211552768193}},
#    'neutral': {'precision': {'mean': 0.5721377477144672,
#      'sd': 0.009604680980220362,
#      'lower': 0.5637188736414702,
#      'upper': 0.5805566217874643},
#     'recall': {'mean': 0.62667004048583,
#      'sd': 0.018751905275105653,
#      'lower': 0.6102332708039429,
#      'upper': 0.6431068101677171},
#     'f1': {'mean': 0.5978967404666724,
#      'sd': 0.006725003549258666,
#      'lower': 0.592002014953325,
#      'upper': 0.6037914659800198}},
#    'positive': {'precision': {'mean': 0.7750406855395953,
#      'sd': 0.008569801481878938,
#      'lower': 0.7675289233420687,
#      'upper': 0.7825524477371218},
#     'recall': {'mean': 0.7095394448053658,
#      'sd': 0.020910497198808917,
#      'lower': 0.6912105858788624,
#      'upper': 0.7278683037318692},
#     'f1': {'mean': 0.7405681391548505,
#      'sd': 0.008703294837908446,
#      'lower': 0.7329393648716223,
#      'upper': 0.7481969134380788}},
#    'macro': {'precision': {'mean': 0.6034145338199965,
#      'sd': 0.019579412642635272,
#      'lower': 0.5862524219496437,
#      'upper': 0.6205766456903494},
#     'recall': {'mean': 0.6425357782511871,
#      'sd': 0.034476927458707764,
#      'lower': 0.6123154188976113,
#      'upper': 0.6727561376047629},
#     'f1': {'mean': 0.6188983064706719,
#      'sd': 0.024368050728456284,
#      'lower': 0.5975387682507393,
#      'upper': 0.6402578446906045}}},
#   '2_few_shot': {'negative': {'precision': {'mean': 0.442812920213024,
#      'sd': 0.07856922257563141,
#      'lower': 0.3739439601466022,
#      'upper': 0.5116818802794458},
#     'recall': {'mean': 0.6045161290322579,
#      'sd': 0.10093424158247459,
#      'lower': 0.5160433654614247,
#      'upper': 0.6929888926030912},
#     'f1': {'mean': 0.5105144526751559,
#      'sd': 0.08575203961249299,
#      'lower': 0.43534947588030265,
#      'upper': 0.5856794294700093}},
#    'neutral': {'precision': {'mean': 0.593862272795562,
#      'sd': 0.01608044045467596,
#      'lower': 0.5797671452733631,
#      'upper': 0.6079574003177609},
#     'recall': {'mean': 0.6055714022819286,
#      'sd': 0.01574723909684681,
#      'lower': 0.5917683386271598,
#      'upper': 0.6193744659366974},
#     'f1': {'mean': 0.5995399151591684,
#      'sd': 0.01351226777466885,
#      'lower': 0.5876958902436273,
#      'upper': 0.6113839400747094}},
#    'positive': {'precision': {'mean': 0.7688220286802127,
#      'sd': 0.00968143781266421,
#      'lower': 0.7603358742771434,
#      'upper': 0.7773081830832819},
#     'recall': {'mean': 0.7332590030375924,
#      'sd': 0.021884727451432058,
#      'lower': 0.7140761936434129,
#      'upper': 0.7524418124317719},
#     'f1': {'mean': 0.7504723635657091,
#      'sd': 0.013887123746799672,
#      'lower': 0.7382997629034692,
#      'upper': 0.762644964227949}},
#    'macro': {'precision': {'mean': 0.6018324072295995,
#      'sd': 0.025368781210038816,
#      'lower': 0.5795956900671488,
#      'upper': 0.6240691243920502},
#     'recall': {'mean': 0.6477821781172597,
#      'sd': 0.03147816223247829,
#      'lower': 0.6201903523782932,
#      'upper': 0.6753740038562261},
#     'f1': {'mean': 0.6201755771333445,
#      'sd': 0.02732660768672641,
#      'lower': 0.596222749399605,
#      'upper': 0.644128404867084}}},
#   '3_few_shot': {'negative': {'precision': {'mean': 0.522147435897436,
#      'sd': 0.048212884673297755,
#      'lower': 0.47988697918926215,
#      'upper': 0.5644078926056098},
#     'recall': {'mean': 0.6563440860215053,
#      'sd': 0.09334819761720799,
#      'lower': 0.5745207831654342,
#      'upper': 0.7381673888775764},
#     'f1': {'mean': 0.5789665187133541,
#      'sd': 0.057246451168247316,
#      'lower': 0.5287877918504874,
#      'upper': 0.6291452455762209}},
#    'neutral': {'precision': {'mean': 0.6279697267699553,
#      'sd': 0.012207140057075745,
#      'lower': 0.6172696967383904,
#      'upper': 0.6386697568015203},
#     'recall': {'mean': 0.584458962090541,
#      'sd': 0.014208217873084213,
#      'lower': 0.5720049100172303,
#      'upper': 0.5969130141638518},
#     'f1': {'mean': 0.6053288226832402,
#      'sd': 0.010818142610549234,
#      'lower': 0.59584630259439,
#      'upper': 0.6148113427720904}},
#    'positive': {'precision': {'mean': 0.7673276947172665,
#      'sd': 0.004081576123280606,
#      'lower': 0.7637500355038043,
#      'upper': 0.7709053539307287},
#     'recall': {'mean': 0.7818587256158587,
#      'sd': 0.007700049944632155,
#      'lower': 0.775109334254173,
#      'upper': 0.7886081169775443},
#     'f1': {'mean': 0.7745033071373015,
#      'sd': 0.004526271891768118,
#      'lower': 0.7705358548965227,
#      'upper': 0.7784707593780804}},
#    'macro': {'precision': {'mean': 0.639148285794886,
#      'sd': 0.015677285234487144,
#      'lower': 0.6254065394039949,
#      'upper': 0.6528900321857771},
#     'recall': {'mean': 0.674220591242635,
#      'sd': 0.03037935767065086,
#      'lower': 0.6475919101678078,
#      'upper': 0.7008492723174622},
#     'f1': {'mean': 0.652932882844632,
#      'sd': 0.020021087738991448,
#      'lower': 0.635383625682826,
#      'upper': 0.670482140006438}}}},
#  'gpt-4o-mini': {'1_few_shot': {'negative': {'precision': {'mean': 0.1591171891171891,
#      'sd': 0.012854685052512579,
#      'lower': 0.14784956087133583,
#      'upper': 0.1703848173630424},
#     'recall': {'mean': 0.7793548387096774,
#      'sd': 0.0742804540109639,
#      'lower': 0.714245150038997,
#      'upper': 0.8444645273803577},
#     'f1': {'mean': 0.26403667181249846,
#      'sd': 0.020865264760835944,
#      'lower': 0.2457474608659845,
#      'upper': 0.2823258827590124}},
#    'neutral': {'precision': {'mean': 0.6850819721339686,
#      'sd': 0.037296333670230546,
#      'lower': 0.652390294273894,
#      'upper': 0.7177736499940433},
#     'recall': {'mean': 0.47702889216047106,
#      'sd': 0.03471890371281881,
#      'lower': 0.44659643126846704,
#      'upper': 0.5074613530524751},
#     'f1': {'mean': 0.561161266263555,
#      'sd': 0.024326099841867465,
#      'lower': 0.5398384996170009,
#      'upper': 0.5824840329101091}},
#    'positive': {'precision': {'mean': 0.7671322928826729,
#      'sd': 0.025242713844751092,
#      'lower': 0.745006078638045,
#      'upper': 0.7892585071273008},
#     'recall': {'mean': 0.6366354713535722,
#      'sd': 0.029185522170132497,
#      'lower': 0.6110532332333248,
#      'upper': 0.6622177094738196},
#     'f1': {'mean': 0.6956369081434498,
#      'sd': 0.025635644093253057,
#      'lower': 0.6731662753503639,
#      'upper': 0.7181075409365357}},
#    'macro': {'precision': {'mean': 0.5371104847112769,
#      'sd': 0.01878127166841611,
#      'lower': 0.520647974250725,
#      'upper': 0.5535729951718288},
#     'recall': {'mean': 0.6310064007412403,
#      'sd': 0.024817579699410057,
#      'lower': 0.6092528330052396,
#      'upper': 0.6527599684772409},
#     'f1': {'mean': 0.5069449487398344,
#      'sd': 0.020668849020508993,
#      'lower': 0.4888279037806315,
#      'upper': 0.5250619936990374}}},
#   '2_few_shot': {'negative': {'precision': {'mean': 0.15733100614336468,
#      'sd': 0.014631545222183386,
#      'lower': 0.14450589128816027,
#      'upper': 0.17015612099856908},
#     'recall': {'mean': 0.7793548387096774,
#      'sd': 0.0742804540109639,
#      'lower': 0.714245150038997,
#      'upper': 0.8444645273803577},
#     'f1': {'mean': 0.26160761527246723,
#      'sd': 0.023467316093071414,
#      'lower': 0.2410376057713029,
#      'upper': 0.28217762477363156}},
#    'neutral': {'precision': {'mean': 0.713326219057117,
#      'sd': 0.031964030094097616,
#      'lower': 0.6853085113600185,
#      'upper': 0.7413439267542156},
#     'recall': {'mean': 0.42324254692675745,
#      'sd': 0.020812429991324637,
#      'lower': 0.404999647697635,
#      'upper': 0.44148544615587987},
#     'f1': {'mean': 0.5305037343850737,
#      'sd': 0.014438480931541077,
#      'lower': 0.5178478478420077,
#      'upper': 0.5431596209281397}},
#    'positive': {'precision': {'mean': 0.7497826195143975,
#      'sd': 0.021071184344849066,
#      'lower': 0.7313129120942848,
#      'upper': 0.7682523269345102},
#     'recall': {'mean': 0.6662686776815971,
#      'sd': 0.02936641066911308,
#      'lower': 0.6405278838011629,
#      'upper': 0.6920094715620314},
#     'f1': {'mean': 0.7053796423995404,
#      'sd': 0.023622053181080932,
#      'lower': 0.6846739998605836,
#      'upper': 0.7260852849384972}},
#    'macro': {'precision': {'mean': 0.5401466149049597,
#      'sd': 0.016179859872423305,
#      'lower': 0.5259643424208252,
#      'upper': 0.5543288873890942},
#     'recall': {'mean': 0.622955354439344,
#      'sd': 0.024147846525905195,
#      'lower': 0.6017888337132188,
#      'upper': 0.6441218751654693},
#     'f1': {'mean': 0.4991636640190271,
#      'sd': 0.016878087324598386,
#      'lower': 0.48436936818853915,
#      'upper': 0.5139579598495151}}},
#   '3_few_shot': {'negative': {'precision': {'mean': 0.17078892934759102,
#      'sd': 0.01793120945734589,
#      'lower': 0.1550715312675493,
#      'upper': 0.18650632742763273},
#     'recall': {'mean': 0.766236559139785,
#      'sd': 0.07176998497588354,
#      'lower': 0.703327393600901,
#      'upper': 0.8291457246786689},
#     'f1': {'mean': 0.27894973483967567,
#      'sd': 0.027191957004705433,
#      'lower': 0.2551149336325967,
#      'upper': 0.30278453604675465}},
#    'neutral': {'precision': {'mean': 0.7204156954156954,
#      'sd': 0.02829350207903255,
#      'lower': 0.695615347379358,
#      'upper': 0.7452160434520327},
#     'recall': {'mean': 0.4223086124401914,
#      'sd': 0.03472241507209648,
#      'lower': 0.3918730737060764,
#      'upper': 0.45274415117430644},
#     'f1': {'mean': 0.5313341528114521,
#      'sd': 0.026684303928269707,
#      'lower': 0.5079443291452288,
#      'upper': 0.5547239764776755}},
#    'positive': {'precision': {'mean': 0.7419661385983882,
#      'sd': 0.025995498924080106,
#      'lower': 0.7191800791387081,
#      'upper': 0.7647521980580684},
#     'recall': {'mean': 0.6935297526030235,
#      'sd': 0.031099809295592057,
#      'lower': 0.6662695678355118,
#      'upper': 0.7207899373705352},
#     'f1': {'mean': 0.716754116261873,
#      'sd': 0.02659620421091649,
#      'lower': 0.6934415154027155,
#      'upper': 0.7400667171210306}},
#    'macro': {'precision': {'mean': 0.5443902544538914,
#      'sd': 0.017649318297811495,
#      'lower': 0.52891994486948,
#      'upper': 0.5598605640383029},
#     'recall': {'mean': 0.6273583080609999,
#      'sd': 0.023902005852510087,
#      'lower': 0.6064072761861542,
#      'upper': 0.6483093399358456},
#     'f1': {'mean': 0.5090126679710002,
#      'sd': 0.022258927376381406,
#      'lower': 0.4895018578808308,
#      'upper': 0.5285234780611696}}}}}

# %% [markdown]
# # **Model Comparisons Within Model Group**
#
# ## **Dictionary Baseline**

# %%
# define remapping dictionaries for plots
main_metrics_remap = {
    "negative": "Negative", "neutral": "Neutral", "positive": "Positive", "macro": "Macro"
}
model_names_remap = {
    "MoritzLaurer/deberta-v3-base-zeroshot-v2.0": "DeBERTa - NLI",
    "microsoft/deberta-v3-base": "DeBERTa",
    "roberta-base": "RoBERTa",
    "bert-base-cased": "BERT",
    "distilbert-base-cased": "DistilBERT",
    "dictionary": "Dictionary",
    "gpt-5-nano": "GPT-5-nano",
    "gpt-4o-mini": "GPT-4o-mini"
}

# all main metrics to look at
focus_metrics = ["negative", "neutral", "positive", "macro"]

# %%
across_metric_barplot(
    eval_results=dictionary_results,
    focus_metrics=focus_metrics,
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# across_metric_dotplot(
#     eval_results=dictionary_results,
#     focus_metrics=focus_metrics,
#     comparison_metric="f1",
#     main_metrics_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
within_metric_barplot(
    eval_results=dictionary_results,
    focus_metrics=["macro"],
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# within_metric_dotplot(
#     eval_results=dictionary_results,
#     focus_metrics=["neutral"],
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
multi_within_metric_barplot(
    eval_results=dictionary_results,
    focus_metrics=focus_metrics,
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance"
)
# multi_within_metric_dotplot(
#     eval_results=dictionary_results,
#     focus_metrics=focus_metrics,
#     metric_title_remap=main_metrics_remap, 
#     model_names_remap=model_names_remap,
#     group_width=1,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance"
# )

# %% [markdown]
# ## **BERT Sequence Classification Models**

# %%
across_metric_barplot(
    eval_results=bert_results,
    focus_metrics=focus_metrics,
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# across_metric_dotplot(
#     eval_results=bert_results,
#     focus_metrics=focus_metrics,
#     comparison_metric="f1",
#     main_metrics_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
within_metric_barplot(
    eval_results=bert_results,
    focus_metrics=["macro"],
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# within_metric_dotplot(
#     eval_results=bert_results,
#     focus_metrics=["macro"],
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
multi_within_metric_barplot(
    eval_results=bert_results,
    focus_metrics=focus_metrics,
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance"
)
# multi_within_metric_dotplot(
#     eval_results=bert_results,
#     focus_metrics=focus_metrics,
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=1,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance"
# )

# %% [markdown]
# ## **BERT NLI Model**

# %%
across_metric_barplot(
    eval_results=nli_results,
    focus_metrics=focus_metrics,
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    printtitle=False
)
# across_metric_dotplot(
#     eval_results=nli_results,
#     focus_metrics=focus_metrics,
#     comparison_metric="f1",
#     main_metrics_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     printtitle=False
# )

# %%
within_metric_barplot(
    eval_results=nli_results,
    focus_metrics=["macro"],
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# within_metric_dotplot(
#     eval_results=nli_results,
#     focus_metrics=["macro"],
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
multi_within_metric_barplot(
    eval_results=nli_results,
    focus_metrics=focus_metrics,
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance"
)
# multi_within_metric_dotplot(
#     eval_results=nli_results,
#     focus_metrics=focus_metrics,
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=1,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance"
# )

# %% [markdown]
# ## **Generative Models**

# %%
few_shot_dev(
    eval_results=gpt_results,
    focus_metrics=["macro"],
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    printtitle=False
)

# %%
multi_few_shot_dev(
    eval_results=gpt_results,
    focus_metrics=focus_metrics,
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1]
)

# %%
# store the best version of each model family
best_gen_llm = {"gpt-5-nano": {},
                "gpt-4o-mini": {}}

for method in gpt_results:
    best_macro_f1 = 0
    best_num_few_shot = None
    for num_few_shot in gpt_results[method]:
        macro_f1_score = gpt_results[method][num_few_shot]["macro"]["f1"]["mean"]
        if macro_f1_score > best_macro_f1:
            best_num_few_shot = num_few_shot
            best_macro_f1 = macro_f1_score
    best_gen_llm[method] = gpt_results[method][best_num_few_shot]
    print(f"Model: {method}")
    print(f"Best performance with {int(best_num_few_shot.split("_")[0])} few-shot examples")
    print(f"Best macro score: {best_macro_f1:.4f}")
    print("-"*50)
# Out:
# Model: gpt-5-nano
# Best performance with 3 few-shot examples
# Best macro score: 0.6529
# --------------------------------------------------
# Model: gpt-4o-mini
# Best performance with 3 few-shot examples
# Best macro score: 0.5090
# --------------------------------------------------

# %%
across_metric_barplot(
    eval_results=best_gen_llm,
    focus_metrics=focus_metrics,
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# across_metric_dotplot(
#     eval_results=best_gen_llm,
#     focus_metrics=focus_metrics,
#     comparison_metric="f1",
#     main_metrics_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
within_metric_barplot(
    eval_results=best_gen_llm,
    focus_metrics=["macro"],
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# within_metric_dotplot(
#     eval_results=best_gen_llm,
#     focus_metrics=["macro"],
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
multi_within_metric_barplot(
    eval_results=best_gen_llm,
    focus_metrics=focus_metrics,
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance"
)
# multi_within_metric_dotplot(
#     eval_results=best_gen_llm,
#     focus_metrics=focus_metrics,
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=1,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance"
# )

# %% [markdown]
# # **Model Comparison Across Model Groups**

# %%
def find_best_model(eval_results):

    best_macro_f1 = 0
    model_name = None

    for model, eval_dict in eval_results.items():
        macro_f1 = eval_dict["macro"]["f1"]["mean"]
        if macro_f1_score > best_macro_f1:
            best_macro_f1 = macro_f1
            model_name = model
    
    return model_name

all_model_families = [nli_results, bert_results, best_gen_llm, dictionary_results]

best_models_each = {}

for model_family in all_model_families:
    best_model_name = find_best_model(model_family)
    best_models_each[best_model_name] = model_family[best_model_name]

# %%
across_metric_barplot(
    eval_results=best_models_each,
    focus_metrics=focus_metrics,
    comparison_metric="f1",
    main_metrics_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# across_metric_dotplot(
#     eval_results=best_models_each,
#     focus_metrics=focus_metrics,
#     comparison_metric="f1",
#     main_metrics_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
within_metric_barplot(
    eval_results=best_models_each,
    focus_metrics=["macro"],
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance",
    printtitle=False
)
# within_metric_dotplot(
#     eval_results=best_models_each,
#     focus_metrics=["macro"],
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=0.3,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance",
#     printtitle=False
# )

# %%
multi_within_metric_barplot(
    eval_results=best_models_each,
    focus_metrics=focus_metrics,
    metric_title_remap=main_metrics_remap,
    model_names_remap=model_names_remap,
    group_width=0.5,
    color_scheme=plt.cm.Set2.colors,
    ylim=[0, 1],
    task="stance"
)
# multi_within_metric_dotplot(
#     eval_results=best_models_each,
#     focus_metrics=focus_metrics,
#     metric_title_remap=main_metrics_remap,
#     model_names_remap=model_names_remap,
#     group_width=1,
#     color_scheme=plt.cm.Set2.colors,
#     marker="o",
#     ylim=[0, 1],
#     task="stance"
# )
