# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# instantiate the classifier pipeline
model_id = "maxwlnd/roberta_group_mention_detector"
tokenizer = AutoTokenizer.from_pretrained("roberta-base")
model = AutoModelForTokenClassification.from_pretrained(model_id)

classifier = pipeline(
    "token-classification",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=0
)
text = "We must take care of the most vulnerable people living in this country."

# prompt it with custom text and print the annotations
annotations = classifier(text)
print(annotations)

# get annotations' character start and end indexes
locations = [(anno['start'], anno['end']) for anno in annotations]
locations

# index the source text using first annotation as an example
loc = locations[0]
text[slice(*loc)]
# Out:
# Device set to use mps:0
# [{'entity_group': 'socialgroup', 'score': 0.9962007, 'word': ' the most vulnerable people living in this country', 'start': 21, 'end': 70}]
# 'the most vulnerable people living in this country'
